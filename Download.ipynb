# %% [markdown]
# #Machine Learning and Remote Sensing for Wildfire and Spatial Risk Management
#
# ## Data aquisiton
#
# Every machine learning algorithm relies havily on data. Remote sensing data is valuble resource for monitoring earth surface and recognizing varieties of phenomenons -  states, eventss, changes
#
# ##Data -> information -> knowledge
# Data - raw values
# Information - values associated with metadata (such as time and place of aquisition, sensor, measuring unit ...)
# Knowledge - detection of circumstances associated with value (Such as wildfire or urban heat island)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.4-cp312-cp312-win_amd64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 11.3 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.5 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------------------------------- ---- 2.4/2.7 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 11.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.4 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3

# %%
# !pip install openeo xarray netCDF4 h5netcdf geopandas matplotlib
# Out:
# Collecting openeo
#   Downloading openeo-0.42.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting xarray
#   Downloading xarray-2025.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting netcdf4
#   Using cached netCDF4-1.7.2-cp312-cp312-win_amd64.whl.metadata (1.8 kB)
# Collecting requests>=2.26.0 (from openeo)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting urllib3>=1.9.0 (from openeo)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting shapely>=1.6.4 (from openeo)
#   Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting numpy>=1.17.0 (from openeo)
#   Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting xarray
#   Using cached xarray-2025.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting pandas>0.20.0 (from openeo)
#   Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pystac<1.12,>=1.5.0 (from openeo)
#   Using cached pystac-1.11.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting deprecated>=1.2.12 (from openeo)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting oschmod>=0.3.12 (from openeo)
#   Using cached oschmod-0.3.12-py2.py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: packaging>=23.2 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from xarray) (25.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from pystac<1.12,>=1.5.0->openeo) (2.9.0.post0)
# Collecting cftime (from netcdf4)
#   Using cached cftime-1.6.4.post1-cp312-cp312-win_amd64.whl.metadata (8.9 kB)
# Collecting certifi (from netcdf4)
#   Downloading certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.12->openeo)
#   Using cached wrapt-1.17.2-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: pywin32 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from oschmod>=0.3.12->openeo) (310)
# Collecting pytz>=2020.1 (from pandas>0.20.0->openeo)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>0.20.0->openeo)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from python-dateutil>=2.7.0->pystac<1.12,>=1.5.0->openeo) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26.0->openeo)
#   Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26.0->openeo)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Downloading openeo-0.42.1-py3-none-any.whl (313 kB)
# Using cached xarray-2025.1.1-py3-none-any.whl (1.2 MB)
# Using cached pystac-1.11.0-py3-none-any.whl (183 kB)
# Using cached netCDF4-1.7.2-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached wrapt-1.17.2-cp312-cp312-win_amd64.whl (38 kB)
# Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl (12.7 MB)
# Using cached oschmod-0.3.12-py2.py3-none-any.whl (14 kB)
# Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.0 MB 11.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/11.0 MB 11.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 11.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.0 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 9.7 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp312-cp312-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.6.15-py3-none-any.whl (157 kB)
# Downloading shapely-2.1.1-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 11.5 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached cftime-1.6.4.post1-cp312-cp312-win_amd64.whl (178 kB)
# Installing collected packages: pytz, wrapt, urllib3, tzdata, oschmod, numpy, idna, charset_normalizer, certifi, shapely, requests, pystac, pandas, deprecated, cftime, xarray, netcdf4, openeo
#
#    ----------------------------------------  0/18 [pytz]
#    ----------------------------------------  0/18 [pytz]
#    -- -------------------------------------  1/18 [wrapt]
#    ---- -----------------------------------  2/18 [urllib3]
#    ---- -----------------------------------  2/18 [urllib3]
#    ---- -----------------------------------  2/18 [urllib3]
#    ---- -----------------------------------  2/18 [urllib3]
#    ---- -----------------------------------  2/18 [urllib3]
#    ------ ---------------------------------  3/18 [tzdata]
#    ------ ---------------------------------  3/18 [tzdata]
#    -------- -------------------------------  4/18 [oschmod]
#    -------- -------------------------------  4/18 [oschmod]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ----------- ----------------------------  5/18 [numpy]
#    ------------- --------------------------  6/18 [idna]
#    --------------- ------------------------  7/18 [charset_normalizer]
#    --------------- ------------------------  7/18 [charset_normalizer]
#    ----------------- ----------------------  8/18 [certifi]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    -------------------- -------------------  9/18 [shapely]
#    ---------------------- ----------------- 10/18 [requests]
#    ---------------------- ----------------- 10/18 [requests]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    ------------------------ --------------- 11/18 [pystac]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    -------------------------- ------------- 12/18 [pandas]
#    ---------------------------- ----------- 13/18 [deprecated]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    --------------------------------- ------ 15/18 [xarray]
#    ----------------------------------- ---- 16/18 [netcdf4]
#    ----------------------------------- ---- 16/18 [netcdf4]
#    ----------------------------------- ---- 16/18 [netcdf4]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ------------------------------------- -- 17/18 [openeo]
#    ---------------------------------------- 18/18 [openeo]
#
# Successfully installed certifi-2025.6.15 cftime-1.6.4.post1 charset_normalizer-3.4.2 deprecated-1.2.18 idna-3.10 netcdf4-1.7.2 numpy-2.3.1 openeo-0.42.1 oschmod-0.3.12 pandas-2.3.0 pystac-1.11.0 pytz-2025.2 requests-2.32.4 shapely-2.1.1 tzdata-2025.2 urllib3-2.5.0 wrapt-1.17.2 xarray-2025.1.1
# Requirement already satisfied: netCDF4 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (1.7.2)
# Collecting h5netcdf
#   Using cached h5netcdf-1.6.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cftime in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from netCDF4) (1.6.4.post1)
# Requirement already satisfied: certifi in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from netCDF4) (2025.6.15)
# Requirement already satisfied: numpy in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from netCDF4) (2.3.1)
# Collecting h5py (from h5netcdf)
#   Downloading h5py-3.14.0-cp312-cp312-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: packaging in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from h5netcdf) (25.0)
# Using cached h5netcdf-1.6.1-py3-none-any.whl (49 kB)
# Downloading h5py-3.14.0-cp312-cp312-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ------------------------- -------------- 1.8/2.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: h5py, h5netcdf
#
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    ---------------------------------------- 0/2 [h5py]
#    -------------------- ------------------- 1/2 [h5netcdf]
#    -------------------- ------------------- 1/2 [h5netcdf]
#    ---------------------------------------- 2/2 [h5netcdf]
#
# Successfully installed h5netcdf-1.6.1 h5py-3.14.0
# Collecting geopandas
#   Downloading geopandas-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from geopandas) (2.3.1)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.11.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: packaging in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from geopandas) (2.3.0)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: shapely>=2.0.0 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.6.15)
# Requirement already satisfied: six>=1.5 in c:\projects\wildfire_remotesensing\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.0-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.11.0-cp312-cp312-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    ---- ----------------------------------- 2.4/19.2 MB 11.2 MB/s eta 0:00:02
#    --------- ------------------------------ 4.7/19.2 MB 11.4 MB/s eta 0:00:02
#    -------------- ------------------------- 7.1/19.2 MB 11.5 MB/s eta 0:00:02
#    ------------------- -------------------- 9.4/19.2 MB 11.5 MB/s eta 0:00:01
#    ------------------------ --------------- 11.8/19.2 MB 11.5 MB/s eta 0:00:01
#    ------------------------------ --------- 14.4/19.2 MB 11.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 16.8/19.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 11.4 MB/s eta 0:00:00
# Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --------------- ------------------------ 2.4/6.3 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: pyproj, pyogrio, geopandas
#
#    ---------------------------------------- 0/3 [pyproj]
#    ---------------------------------------- 0/3 [pyproj]
#    ---------------------------------------- 0/3 [pyproj]
#    ---------------------------------------- 0/3 [pyproj]
#    ---------------------------------------- 0/3 [pyproj]
#    ------------- -------------------------- 1/3 [pyogrio]
#    ------------- -------------------------- 1/3 [pyogrio]
#    ------------- -------------------------- 1/3 [pyogrio]
#    ------------- -------------------------- 1/3 [pyogrio]
#    ------------- -------------------------- 1/3 [pyogrio]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    -------------------------- ------------- 2/3 [geopandas]
#    ---------------------------------------- 3/3 [geopandas]
#
# Successfully installed geopandas-1.1.0 pyogrio-0.11.0 pyproj-3.7.1

# %%
import openeo
import xarray
import matplotlib.pyplot as plt

# %% [markdown]
# #OpenEO

# %%
connection = openeo.connect(url="openeo.dataspace.copernicus.eu")
connection
connection.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeo.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>

# %%
s2_cube = connection.load_collection(
    "SENTINEL2_L2A",
    temporal_extent=("2024-07-15", "2024-08-15"),
    spatial_extent={
        "west": 15.74,
        "south": 43.7,
        "east": 16.00,
        "north": 43.93,
        "crs": "EPSG:4326",
    },
    #bands=["B04", "B03", "B02", "SCL"],
    bands=['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B09', 'B11', 'B12'],
    max_cloud_cover=50,
)
s2_cube.download("fire_krka.nc")

# %%
ds = xarray.load_dataset("fire_krka.nc")
# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")
data

# %% [markdown]
# Compare images from 3 timestamps - before, during and after fire
# Burned area is visible on the third image

# %%
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000)

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 3), dpi=90, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": 2}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);
data[{"t": 3}].plot.imshow(vmin=0, vmax=2000, ax=axes[2]);

# %% [markdown]
# <h2> Explore netCDF</h2>

# %%
import netCDF4

# Open the NetCDF file
fp = 'fire_krka.nc'
nc = netCDF4.Dataset(fp)

# List all variables
print(nc.variables.keys())

# List all dimensions
print(nc.dimensions.keys())

# Access a variable (e.g., 'Temp')
temp = nc.variables['t'][:]
print(temp)
# Print CRS
print(nc.variables['crs'])
# Close the file when done
nc.close()

# %% [markdown]
# <h2> Load Burned areas from effis</h2>

# %%
import geopandas as gpd
import pandas as pd
# Load shapefile
gdf1 = gpd.read_file("effis_layer/modis.ba.poly.shp")

import pandas as pd
#df = pd.DataFrame(gdf.drop(columns='geometry'))
# Convert date column to datetime
gdf1['date'] = pd.to_datetime(gdf1['FIREDATE'],format='mixed')

# Define filter criteria
countries_to_keep = ['HR' ]
start_date = '2024-01-01'
end_date = '2024-12-31'

# Filter by country and date range
gdf = gdf1[
    (gdf1['COUNTRY'].isin(countries_to_keep)) &
    (gdf1['date'] >= start_date) &
    (gdf1['date'] <= end_date)
]

# %% [markdown]
# Create bounding boxes around every fire

# %%
# Extract bounding box coordinates (west, south, east, north) for each geometry
gdf['bbox'] = gdf.geometry.apply(lambda geom: geom.bounds)  # bounds = (minx, miny, maxx, maxy)

# Split bounds tuple into separate columns
gdf[['west', 'south', 'east', 'north']] = gdf['bbox'].apply(pd.Series)
 

# Example: 10 days before and 10 days after fire date
gdf['start_date_before'] = gdf['date'] - pd.Timedelta(days=10)
gdf['end_date_before'] = gdf['date'] - pd.Timedelta(days=1)

gdf['start_date_after'] = gdf['date'] + pd.Timedelta(days=2)
gdf['end_date_after'] = gdf['date'] + pd.Timedelta(days=10)

# %%
import openeo
import xarray
import matplotlib.pyplot as plt
connection = openeo.connect(url="openeo.dataspace.copernicus.eu")
connection
 
connection.authenticate_oidc()

# %%
Downlaod EO data

# %%
'''
from openeo.rest.connection import OpenEoApiError
import os
import time
all_bands = [
 'B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B09', 'B11', 'B12', 'WVP', 'AOT', 'SCL', 'sunAzimuthAngles', 'sunZenithAngles', 'viewAzimuthMean', 'viewZenithMean'
]
for idx, row in gdf.iterrows():
    id = row['id']
    file_before = f"fire_{id}_before.nc"
    file_after = f"fire_{id}_after.nc"
    spatial_extent = {
        "west": row['west'],
        "south": row['south'],
        "east": row['east'],
        "north": row['north'],
        "crs": "EPSG:4326",
    }
    if os.path.exists(file_after):
        print(f"File {file_after} already exists, skipping download.")
    else:
    # Define date ranges as strings
        print(f"downloading {file_before} ." )
        before_start = row['start_date_before'].strftime('%Y-%m-%d')
        before_end = row['end_date_before'].strftime('%Y-%m-%d')
        after_start = row['start_date_after'].strftime('%Y-%m-%d')
        after_end = row['end_date_after'].strftime('%Y-%m-%d')
        
        # Download before fire
        try:
            s2_cube_before = connection.load_collection(
                "SENTINEL2_L2A",
                temporal_extent=(before_start, before_end),
                spatial_extent=spatial_extent,
                bands=all_bands,
                
            ).reduce_dimension(dimension="t", reducer="last")
            s2_cube_before.download(file_before)
            print(f"  {file_before} . downloaded , sleeping" )
            time.sleep(5)
        except OpenEoApiError as e:
            if "NoDataAvailable" in str(e):
                print(f"No data available for fire_{id}_before.nc, skipping download.")
            else:
                raise  # re-raise other errors
        
        # Download after fire

        print(f"downloading {file_after}  " )
        try:
            s2_cube_after = connection.load_collection(
                "SENTINEL2_L2A",
                temporal_extent=(after_start, after_end),
                spatial_extent=spatial_extent,
                bands=all_bands,
               
            ).reduce_dimension(dimension="t", reducer="first")
            s2_cube_after.download(file_after)
            print(f"  {file_before} . downloaded , sleeping" )

            time.sleep(5)
        except OpenEoApiError as e:
            if "NoDataAvailable" in str(e):
                print(f"No data available for fire_{id}_after.nc, skipping download.")
            else:
                raise
'''
